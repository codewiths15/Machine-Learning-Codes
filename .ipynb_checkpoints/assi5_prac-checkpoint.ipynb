# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("sales_data_sample.csv", encoding="ISO-8859-1")
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
features=df[['QUANTITYORDERED','SALES']]
features=features.dropna()

# %%
print(features)
# Out:
#       QUANTITYORDERED    SALES
# 0                  30  2871.00
# 1                  34  2765.90
# 2                  41  3884.34
# 3                  45  3746.70
# 4                  49  5205.27
# ...               ...      ...
# 2818               20  2244.40
# 2819               29  3978.51
# 2820               43  5417.57
# 2821               34  2116.16
# 2822               47  3079.44
#
# [2823 rows x 2 columns]

# %%
wcss=[]

for k in range(1,11):
    k_means=KMeans(n_clusters=k, init="k-means++", random_state=42)
    k_means.fit(features)
    wcss.append(k_means.inertia_)
# Out:
# C:\Users\SAHIL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\SAHIL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\SAHIL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
print(wcss)
# Out:
# [9573809860.85561, 3321660281.248889, 1729080363.3337812, 1039766596.6157286, 712111213.7937407, 511616511.70934844, 386478042.6900463, 295131316.5085027, 231717097.93433607, 187968708.06218207]

# %%
plt.plot(range(1,11), wcss)
plt.title("Elbow method")
plt.xlabel("wcss value")
plt.ylabel("Number of clusters")
plt.show()

# %%
k_means=KMeans(n_clusters=3, init="k-means++", random_state=42)
features["Clusters"]=k_means.fit_predict(features)
# Out:
# C:\Users\SAHIL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
plt.scatter(features['QUANTITYORDERED'], features['SALES'], c=features['Clusters'], cmap="viridis")
plt.title("Clusters plotting")
plt.xlabel("Quantity ordered")
plt.ylabel("Sales")
plt.show()
